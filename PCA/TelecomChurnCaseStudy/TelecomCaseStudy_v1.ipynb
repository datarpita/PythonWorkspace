# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
telecom_orig_df = pd.read_csv('telecom_churn_data.csv')

# %%
print('No. of rows and columns---',telecom_orig_df.shape)
# Out:
# No. of rows and columns--- (99999, 226)

# %%
telecom_orig_df.describe()
# Out:
#        mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count   9.999900e+04    99999.0         98981.0         98981.0
# mean    7.001207e+09      109.0             0.0             0.0
# std     6.956694e+05        0.0             0.0             0.0
# min     7.000000e+09      109.0             0.0             0.0
# 25%     7.000606e+09      109.0             0.0             0.0
# 50%     7.001205e+09      109.0             0.0             0.0
# 75%     7.001812e+09      109.0             0.0             0.0
# max     7.002411e+09      109.0             0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8        arpu_9  \
# count         98981.0  99999.000000  99999.000000  99999.000000  99999.000000
# mean              0.0    282.987358    278.536648    279.154731    261.645069
# std               0.0    328.439770    338.156291    344.474791    341.998630
# ...

# %%
telecom_copy_df = telecom_orig_df

# %%
telecom_copy_df['70THPERC_JunJul']=(telecom_copy_df['total_rech_amt_6'] +  telecom_copy_df['total_rech_amt_7'])/2
np.percentile(telecom_copy_df['70THPERC_JunJul'].values,0.7, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-27-bd14bb339249> in <module>
#       1 telecom_copy_df['70THPERC_JunJul']=(telecom_copy_df['total_rech_amt_6'] +  telecom_copy_df['total_rech_amt_7'])/2
# ----> 2 np.percentile(telecom_copy_df['70THPERC_JunJul'].values,0.7, axis=1)
#
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3538         raise ValueError("Percentiles must be in the range [0, 100]")
#    3539     return _quantile_unchecked(
# -> 3540         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3541
#    3542
#
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3650     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
# ...

# %%
telecom_copy_df.head(10)
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
# 5     7000286308        109             0.0             0.0             0.0
# 6     7001051193        109             0.0             0.0             0.0
# 7     7000701601        109             0.0             0.0             0.0
# 8     7001524846        109             0.0             0.0             0.0
# 9     7001864400        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# ...
