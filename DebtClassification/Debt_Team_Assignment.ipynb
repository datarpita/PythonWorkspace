# %%
import numpy as np
import pandas as pd

# %%
inc_task_df_raw = pd.read_csv('POC Data\\sd0009c-incidents at task level\\2019\\SD0009c_Incidents_Tasks_Extract (1).csv')

# %%
inc_task_df_raw.shape
# Out:
# (107692, 34)

# %%
inc_task_df_raw.columns
# Out:
# Index(['Textbox11', 'IncidentNumber', 'Status', 'Source', 'IncidentPriority',
#        'IncidentCreatedDateTime', 'ResolvedDateTime', 'IncidentClosedDateTime',
#        'Environment', 'AssetNumber', 'Summary', 'ActualService',
#        'ActualCategory', 'Service', 'Category', 'IncidentOwner',
#        'IncidentOwnerTeam', 'CustomerName', 'BusinessStream', 'CauseCode',
#        'ResolutionCode', 'ResolvedByName', 'ResolvedByTeam', 'Breach',
#        'TaskLastModDateTime1', 'TaskOwnerTeam', 'TaskSubject', 'TaskStatus',
#        'TaskCreatedDateTime', 'TaskAssignedDateTime',
#        'TaskAcknowledgeDateTime', 'TaskLastModDateTime',
#        'TaskResolvedDateTime', 'TaskResolvedBy'],
#       dtype='object')

# %%
inc_task_df_sel_col = inc_task_df_raw[['IncidentNumber','ResolvedDateTime','Summary', 'ActualService',
       'ActualCategory','CauseCode','ResolutionCode','ResolvedByTeam','TaskSubject', 'TaskStatus','TaskResolvedDateTime']]

# %%
inc_task_df_sel_col.shape
# Out:
# (107692, 11)

# %%
inc_task_df_sel_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107692 entries, 0 to 107691
# Data columns (total 11 columns):
# IncidentNumber          107692 non-null int64
# ResolvedDateTime        107062 non-null object
# Summary                 107692 non-null object
# ActualService           107503 non-null object
# ActualCategory          107503 non-null object
# CauseCode               107238 non-null object
# ResolutionCode          107243 non-null object
# ResolvedByTeam          107062 non-null object
# TaskSubject             107692 non-null object
# TaskStatus              107692 non-null object
# TaskResolvedDateTime    93579 non-null object
# dtypes: int64(1), object(10)
# memory usage: 9.0+ MB

# %%
inc_task_df_sel_col['IncidentNumber'].unique()
# Out:
# array([638340, 638341, 638342, ..., 733219, 733221, 733222], dtype=int64)

# %%
inc_task_df_sel_col['TaskResolvedDateTime'] = pd.to_datetime(inc_task_df_sel_col.TaskResolvedDateTime)
# Out:
# D:\Arpita_Datta\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
inc_task_df_sel_col.sort_values(by=['IncidentNumber','TaskResolvedDateTime'],ascending=False, inplace=True)
# Out:
# D:\Arpita_Datta\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
inc_task_df_sel_col.loc[inc_task_df_sel_col['IncidentNumber']==676702]
# Out:
#        IncidentNumber ResolvedDateTime                           Summary  \
# 44169          676702              NaN  Unable to send messages to gmail
# 44167          676702              NaN  Unable to send messages to gmail
# 44168          676702              NaN  Unable to send messages to gmail
#
#                        ActualService     ActualCategory CauseCode  \
# 44169  Communication & Collaboration  Mimecast Tracking     Other
# 44167  Communication & Collaboration  Mimecast Tracking     Other
# 44168  Communication & Collaboration  Mimecast Tracking     Other
#
#              ResolutionCode ResolvedByTeam                       TaskSubject  \
# 44169  Automatically Closed            NaN  Unable to send messages to gmail
# 44167  Automatically Closed            NaN  Unable to send messages to gmail
# 44168  Automatically Closed            NaN  Unable to send messages to gmail
#
#        TaskStatus TaskResolvedDateTime
# 44169   Cancelled  2019-08-19 12:00:09
# ...

# %%
inc_task_df_sel_col.head(50)
# Out:
#         IncidentNumber     ResolvedDateTime  \
# 107691          733222  07/01/2020 21:59:29
# 107690          733221  02/01/2020 15:18:09
# 107688          733219  08/01/2020 10:38:22
# 107689          733219  08/01/2020 10:38:22
# 107687          733218  31/12/2019 09:52:16
# 107686          733218  31/12/2019 09:52:16
# 107685          733217  30/12/2019 18:00:27
# 107684          733216  31/12/2019 06:33:11
# 107683          733215  30/12/2019 15:50:46
# 107682          733214  02/01/2020 12:23:16
# 107681          733213  02/01/2020 08:19:21
# 107680          733212  30/12/2019 14:34:50
# 107677          733210  02/01/2020 09:48:16
# 107679          733210  02/01/2020 09:48:16
# 107678          733210  02/01/2020 09:48:16
# 107676          733209  30/12/2019 14:22:58
# 107675          733208  13/01/2020 16:23:52
# 107674          733208  13/01/2020 16:23:52
# 107673          733206  30/12/2019 13:12:27
# 107672          733205  31/12/2019 10:03:40
# ...

# %%
inc_task_df = inc_task_df_sel_col.groupby(by='IncidentNumber').first()

# %%
inc_task_df.shape
# Out:
# (74914, 10)

# %%
inc_task_df.to_csv('Incident_Task_2019.csv')
