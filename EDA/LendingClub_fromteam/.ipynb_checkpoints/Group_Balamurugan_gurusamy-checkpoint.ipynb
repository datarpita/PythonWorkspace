# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
from pandas.tools.plotting import scatter_matrix

# %%
# %matplotlib inline

# %% [markdown]
# ### Loading the data

# %%
zf = zipfile.ZipFile('loan.zip')

# %%
date_mon_yy = lambda x: pd.datetime.strptime(x, '%d-%B-%y')

# %%
loans_df = pd.read_csv(zf.open(zipfile.ZipFile.namelist(zf)[0]),parse_dates=True)
# Out:
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print('Total no. of columns is ',len(loans_df.columns))
# Out:
# Total no. of columns is  111

# %%
loans_df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# 50%        8975.000000    280.220000  5.900000e+04     13.400000
# 75%       14400.000000    430.780000  8.230000e+04     18.600000
# max       35000.000000   1305.190000  6.000000e+06     29.990000
#
#         delinq_2yrs  inq_last_6mths             ...              \
# count  39717.000000    39717.000000             ...
# mean       0.146512        0.869200             ...
# std        0.491812        1.070219             ...
# min        0.000000        0.000000             ...
# 25%        0.000000        0.000000             ...
# 50%        0.000000        1.000000             ...
# 75%        0.000000        1.000000             ...
# max       11.000000        8.000000             ...
#
#        num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# count                 0.0                 0.0             0.0
# mean                  NaN                 NaN             NaN
# std                   NaN                 NaN             NaN
# min                   NaN                 NaN             NaN
# 25%                   NaN                 NaN             NaN
# 50%                   NaN                 NaN             NaN
# 75%                   NaN                 NaN             NaN
# max                   NaN                 NaN             NaN
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# count               0.0          39020.000000    39678.0              0.0
# mean                NaN              0.043260        0.0              NaN
# std                 NaN              0.204324        0.0              NaN
# min                 NaN              0.000000        0.0              NaN
# 25%                 NaN              0.000000        0.0              NaN
# 50%                 NaN              0.000000        0.0              NaN
# 75%                 NaN              0.000000        0.0              NaN
# max                 NaN              2.000000        0.0              NaN
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# count                0.0             0.0                         0.0
# mean                 NaN             NaN                         NaN
# std                  NaN             NaN                         NaN
# min                  NaN             NaN                         NaN
# 25%                  NaN             NaN                         NaN
# 50%                  NaN             NaN                         NaN
# 75%                  NaN             NaN                         NaN
# max                  NaN             NaN                         NaN
#
# [8 rows x 87 columns]

# %%
total_rows = loans_df.shape[0]
print('Total no. of observations is ',total_rows)
# Out:
# Total no. of observations is  39717

# %% [markdown]
# ### % of missing fields

# %%
round((loans_df.isna().sum()/total_rows)*100,2)
# Out:
# id                                  0.00
# member_id                           0.00
# loan_amnt                           0.00
# funded_amnt                         0.00
# funded_amnt_inv                     0.00
# term                                0.00
# int_rate                            0.00
# installment                         0.00
# grade                               0.00
# sub_grade                           0.00
# emp_title                           6.19
# emp_length                          2.71
# home_ownership                      0.00
# annual_inc                          0.00
# verification_status                 0.00
# issue_d                             0.00
# loan_status                         0.00
# pymnt_plan                          0.00
# url                                 0.00
# desc                               32.58
# purpose                             0.00
# title                               0.03
# zip_code                            0.00
# addr_state                          0.00
# dti                                 0.00
# delinq_2yrs                         0.00
# earliest_cr_line                    0.00
# inq_last_6mths                      0.00
# mths_since_last_delinq             64.66
# mths_since_last_record             92.99
#                                    ...
# mo_sin_old_rev_tl_op              100.00
# mo_sin_rcnt_rev_tl_op             100.00
# mo_sin_rcnt_tl                    100.00
# mort_acc                          100.00
# mths_since_recent_bc              100.00
# mths_since_recent_bc_dlq          100.00
# mths_since_recent_inq             100.00
# mths_since_recent_revol_delinq    100.00
# num_accts_ever_120_pd             100.00
# num_actv_bc_tl                    100.00
# num_actv_rev_tl                   100.00
# num_bc_sats                       100.00
# num_bc_tl                         100.00
# num_il_tl                         100.00
# num_op_rev_tl                     100.00
# num_rev_accts                     100.00
# num_rev_tl_bal_gt_0               100.00
# num_sats                          100.00
# num_tl_120dpd_2m                  100.00
# num_tl_30dpd                      100.00
# num_tl_90g_dpd_24m                100.00
# num_tl_op_past_12m                100.00
# pct_tl_nvr_dlq                    100.00
# percent_bc_gt_75                  100.00
# pub_rec_bankruptcies                1.75
# tax_liens                           0.10
# tot_hi_cred_lim                   100.00
# total_bal_ex_mort                 100.00
# total_bc_limit                    100.00
# total_il_high_credit_limit        100.00
# Length: 111, dtype: float64

# %% [markdown]
# #### Removing the columns whose values are null

# %%
loans_df1 = loans_df.dropna(axis=1,how='all')

# %% [markdown]
# #### After removing null columns finally we got 57 columns

# %%
print('no. of columns after removing na/null is',len(loans_df1.columns))
# Out:
# no. of columns after removing na/null is 57

# %%
 round((loans_df1.isna().sum()/loans_df1.shape[0])*100,2)
# Out:
# id                             0.00
# member_id                      0.00
# loan_amnt                      0.00
# funded_amnt                    0.00
# funded_amnt_inv                0.00
# term                           0.00
# int_rate                       0.00
# installment                    0.00
# grade                          0.00
# sub_grade                      0.00
# emp_title                      6.19
# emp_length                     2.71
# home_ownership                 0.00
# annual_inc                     0.00
# verification_status            0.00
# issue_d                        0.00
# loan_status                    0.00
# pymnt_plan                     0.00
# url                            0.00
# desc                          32.58
# purpose                        0.00
# title                          0.03
# zip_code                       0.00
# addr_state                     0.00
# dti                            0.00
# delinq_2yrs                    0.00
# earliest_cr_line               0.00
# inq_last_6mths                 0.00
# mths_since_last_delinq        64.66
# mths_since_last_record        92.99
# open_acc                       0.00
# pub_rec                        0.00
# revol_bal                      0.00
# revol_util                     0.13
# total_acc                      0.00
# initial_list_status            0.00
# out_prncp                      0.00
# out_prncp_inv                  0.00
# total_pymnt                    0.00
# total_pymnt_inv                0.00
# total_rec_prncp                0.00
# total_rec_int                  0.00
# total_rec_late_fee             0.00
# recoveries                     0.00
# collection_recovery_fee        0.00
# last_pymnt_d                   0.18
# last_pymnt_amnt                0.00
# next_pymnt_d                  97.13
# last_credit_pull_d             0.01
# collections_12_mths_ex_med     0.14
# policy_code                    0.00
# application_type               0.00
# acc_now_delinq                 0.00
# chargeoff_within_12_mths       0.14
# delinq_amnt                    0.00
# pub_rec_bankruptcies           1.75
# tax_liens                      0.10
# dtype: float64

# %% [markdown]
# #### next_pymnt_d is 97% empty

# %%
loans_df1.next_pymnt_d.value_counts()
# Out:
# Jun-16    1125
# Jul-16      15
# Name: next_pymnt_d, dtype: int64

# %%
loans_df1.drop(columns='next_pymnt_d',axis=1,inplace=True)
print('no of colls After droping next_pymnt_d ',len(loans_df1.columns))
# Out:
# no of colls After droping next_pymnt_d  56
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
round((loans_df1.isna().sum()/loans_df1.shape[0])*100,2)
# Out:
# id                             0.00
# member_id                      0.00
# loan_amnt                      0.00
# funded_amnt                    0.00
# funded_amnt_inv                0.00
# term                           0.00
# int_rate                       0.00
# installment                    0.00
# grade                          0.00
# sub_grade                      0.00
# emp_title                      6.19
# emp_length                     2.71
# home_ownership                 0.00
# annual_inc                     0.00
# verification_status            0.00
# issue_d                        0.00
# loan_status                    0.00
# pymnt_plan                     0.00
# url                            0.00
# desc                          32.58
# purpose                        0.00
# title                          0.03
# zip_code                       0.00
# addr_state                     0.00
# dti                            0.00
# delinq_2yrs                    0.00
# earliest_cr_line               0.00
# inq_last_6mths                 0.00
# mths_since_last_delinq        64.66
# mths_since_last_record        92.99
# open_acc                       0.00
# pub_rec                        0.00
# revol_bal                      0.00
# revol_util                     0.13
# total_acc                      0.00
# initial_list_status            0.00
# out_prncp                      0.00
# out_prncp_inv                  0.00
# total_pymnt                    0.00
# total_pymnt_inv                0.00
# total_rec_prncp                0.00
# total_rec_int                  0.00
# total_rec_late_fee             0.00
# recoveries                     0.00
# collection_recovery_fee        0.00
# last_pymnt_d                   0.18
# last_pymnt_amnt                0.00
# last_credit_pull_d             0.01
# collections_12_mths_ex_med     0.14
# policy_code                    0.00
# application_type               0.00
# acc_now_delinq                 0.00
# chargeoff_within_12_mths       0.14
# delinq_amnt                    0.00
# pub_rec_bankruptcies           1.75
# tax_liens                      0.10
# dtype: float64

# %%
loans_df1['revol_util'].head()
# Out:
# 0    83.70%
# 1     9.40%
# 2    98.50%
# 3       21%
# 4    53.90%
# Name: revol_util, dtype: object

# %%
loans_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 56 columns):
# id                            39717 non-null int64
# member_id                     39717 non-null int64
# loan_amnt                     39717 non-null int64
# funded_amnt                   39717 non-null int64
# funded_amnt_inv               39717 non-null float64
# term                          39717 non-null object
# int_rate                      39717 non-null object
# installment                   39717 non-null float64
# grade                         39717 non-null object
# sub_grade                     39717 non-null object
# emp_title                     37258 non-null object
# emp_length                    38642 non-null object
# home_ownership                39717 non-null object
# annual_inc                    39717 non-null float64
# verification_status           39717 non-null object
# issue_d                       39717 non-null object
# loan_status                   39717 non-null object
# pymnt_plan                    39717 non-null object
# url                           39717 non-null object
# desc                          26777 non-null object
# purpose                       39717 non-null object
# title                         39706 non-null object
# zip_code                      39717 non-null object
# addr_state                    39717 non-null object
# dti                           39717 non-null float64
# delinq_2yrs                   39717 non-null int64
# earliest_cr_line              39717 non-null object
# inq_last_6mths                39717 non-null int64
# mths_since_last_delinq        14035 non-null float64
# mths_since_last_record        2786 non-null float64
# open_acc                      39717 non-null int64
# pub_rec                       39717 non-null int64
# revol_bal                     39717 non-null int64
# revol_util                    39667 non-null object
# total_acc                     39717 non-null int64
# initial_list_status           39717 non-null object
# out_prncp                     39717 non-null float64
# out_prncp_inv                 39717 non-null float64
# total_pymnt                   39717 non-null float64
# total_pymnt_inv               39717 non-null float64
# total_rec_prncp               39717 non-null float64
# total_rec_int                 39717 non-null float64
# total_rec_late_fee            39717 non-null float64
# recoveries                    39717 non-null float64
# collection_recovery_fee       39717 non-null float64
# last_pymnt_d                  39646 non-null object
# last_pymnt_amnt               39717 non-null float64
# last_credit_pull_d            39715 non-null object
# collections_12_mths_ex_med    39661 non-null float64
# policy_code                   39717 non-null int64
# application_type              39717 non-null object
# acc_now_delinq                39717 non-null int64
# chargeoff_within_12_mths      39661 non-null float64
# delinq_amnt                   39717 non-null int64
# pub_rec_bankruptcies          39020 non-null float64
# tax_liens                     39678 non-null float64
# dtypes: float64(20), int64(13), object(23)
# memory usage: 13.5+ MB

# %% [markdown]
# ### Data Cleaning

# %%
loans_df1.loc['revol_util'] =loans_df1.revol_util.apply(lambda x: float(str(x).replace('%','')))
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
loans_df1.loc['term'] =loans_df1.term.apply(lambda x: str(x).replace('months','').strip())
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ##### Catagerical column: 'emp_length' re-arranging to range as per definition

# %%
loans_df1.emp_length.value_counts()/total_rows
# Out:
# 10+ years    0.223557
# < 1 year     0.115391
# 2 years      0.110482
# 3 years      0.103104
# 4 years      0.086512
# 5 years      0.082635
# 1 year       0.081577
# 6 years      0.056122
# 7 years      0.044641
# 8 years      0.037238
# 9 years      0.031674
# Name: emp_length, dtype: float64

# %%
loans_df1.emp_length.unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %% [markdown]
# ###### Creating dict for emp_length

# %%
## 0-1, 1-9,10+, na
## corr the title company..... revisit
emp_len_dict = {k:'0-10 years' for k in loans_df1.emp_length.unique()}
emp_len_dict['n/a']='n/a'
emp_len_dict['10+ years'] = '10+ years'
emp_len_dict['< 1 year']='0 years'


print(emp_len_dict)
# Out:
# {'10+ years': '10+ years', '< 1 year': '0 years', '1 year': '0-10 years', '3 years': '0-10 years', '8 years': '0-10 years', '9 years': '0-10 years', '4 years': '0-10 years', '5 years': '0-10 years', '6 years': '0-10 years', '2 years': '0-10 years', '7 years': '0-10 years', nan: '0-10 years', 'n/a': 'n/a'}

# %% [markdown]
# ##### Replacing nan to 'n/a' for emp_length

# %%
loans_df1.emp_length.fillna('n/a',inplace=True,axis=0)
# Out:
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
loans_df1['emp_length_range'] = loans_df1.emp_length.map(emp_len_dict)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
loans_df1['emp_length_range'].unique()
# Out:
# array(['10+ years', '0 years', '0-10 years', 'n/a'], dtype=object)

# %%
(loans_df1.emp_length_range.value_counts()/total_rows)*100
# Out:
# 0-10 years    63.398545
# 10+ years     22.355666
# 0 years       11.539139
# n/a            2.711685
# Name: emp_length_range, dtype: float64

# %%
# from above emp_lenght % , n/a is 2% of total row's. so it can ignore

# %%
loanData = loans_df1.copy()

# %%
loanData.drop(columns=['url'],axis=1,inplace=True)

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt',
#        'pub_rec_bankruptcies', 'tax_liens', 'emp_length_range'],
#       dtype='object')

# %% [markdown]
# ##### convert to date

# %%
col_date =['issue_d','last_pymnt_d','last_credit_pull_d']

# %%
loanData['issue_d'].head()
# Out:
# 0    Dec-11
# 1    Dec-11
# 2    Dec-11
# 3    Dec-11
# 4    Dec-11
# Name: issue_d, dtype: object

# %%
loanData['issue_d'] = pd.to_datetime(loanData['issue_d'],format='%b-%y')

# %%
loanData.drop(columns=['tax_liens','delinq_amnt','chargeoff_within_12_mths','acc_now_delinq','policy_code','collections_12_mths_ex_med'],axis=1,inplace=True)

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'application_type', 'pub_rec_bankruptcies', 'emp_length_range'],
#       dtype='object')

# %%
loanData['int_rate'] = loanData['int_rate'].str.rstrip('%').astype('float')

# %%
loanData = loanData.drop(['title', 'zip_code'], axis=1)

# %%
loanData['revol_util'] = loanData['revol_util'].str.rstrip('%').astype('float')

# %%
# Filter data of loan_status for only charged off and fully paid, as we don't need the current status coustomer
loanData = loanData[loanData['loan_status'].isin(['Charged Off','Fully Paid'])]
print(loanData.shape)
print(loanData.shape)
# Out:
# (38577, 48)
# (38577, 48)

# %%
loanData['loan_status'] = loanData['loan_status'].apply(lambda x: 0 if x=='Fully Paid' else 1)

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'application_type', 'pub_rec_bankruptcies', 'emp_length_range'],
#       dtype='object')

# %% [markdown]
# ### Univariate Analysis

# %%
# plotting default rates across grade of the loan
sns.barplot(x='home_ownership', y='loan_status', data=loanData)
plt.ylabel('')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='verification_status', y='loan_status', data=loanData)
plt.ylabel('')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x='addr_state', y='loan_status', data=loanData)
plt.ylabel('')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x='purpose', y='loan_status', data=loanData)
plt.ylabel('')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='grade', y='loan_status', data=loanData)
plt.ylabel('')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x='sub_grade', y='loan_status', data=loanData)
plt.ylabel('')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='term', y='loan_status', data=loanData)
plt.ylabel('')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='emp_length_range', y='loan_status', data=loanData)
plt.ylabel('')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# boxplot for spread of annual income & DTI 
sns.set_style('whitegrid')
plt.figure(num=None,figsize=(20,20),dpi=80)
plt.subplot(321)
plt.title('DTI by Loan Status')
sns.boxplot(x = 'loan_status', y = 'dti', data = loanData)
plt.subplot(322)
plt.title('Annual Income by Loan Status')
plt.yscale('log')
sns.boxplot(x = 'loan_status', y = 'annual_inc', data = loanData)

# %%
#Plotting histogram for defaulters and all customers to compare trends
loan_col = ['loan_amnt','funded_amnt','funded_amnt_inv','annual_inc','installment','int_rate','dti','revol_bal',
           'open_acc','total_acc']
loanData_defaulted = loanData.loc[loanData.loan_status == 1]

for col in list(loan_col):
    print(col)
    plt.figure(figsize=(8, 4))
    x = loanData[col]
    y = loanData_defaulted[col]
    plt.hist(x, 100, label='all customers')
    plt.hist(y, 100, label='default customers')
    plt.legend(loc='upper right')
    plt.xlabel(col)
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
# Out:
# loan_amnt
# funded_amnt
# funded_amnt_inv
# annual_inc
# installment
# int_rate
# dti
# revol_bal
# open_acc
# total_acc

# %% [markdown]
# ### Feature  analysis

# %%
#Derive the percentage of loans of each term that default.
loan_term = loanData.groupby(['term','loan_status']).size().to_frame('LoanStatusPercentage')
loan_term.groupby(level=[0]).apply(lambda x: x / x.sum()*100)
# Out:
#                         LoanStatusPercentage
# term       loan_status
#  36 months 0                       88.909128
#            1                       11.090872
#  60 months 0                       74.686215
#            1                       25.313785

# %%
#Derive the percentage of loans of each grade that default.
loan_grade = loanData.groupby(['grade','loan_status']).size().to_frame('LoanStatusPercentage')
loan_grade.groupby(level=[0]).apply(lambda x: x / x.sum()*100)
# Out:
#                    LoanStatusPercentage
# grade loan_status
# A     0                       94.006969
#       1                        5.993031
# B     0                       87.794433
#       1                       12.205567
# C     0                       82.805719
#       1                       17.194281
# D     0                       78.013766
#       1                       21.986234
# E     0                       73.150582
#       1                       26.849418
# F     0                       67.315574
#       1                       32.684426
# G     0                       66.220736
#       1                       33.779264

# %%
#Derive the percentage of loans of each employee tenure that default.
loan_emp_tenure = loanData.groupby(['emp_length_range','loan_status']).size().to_frame('LoanStatusPercentage')
loan_emp_tenure.groupby(level=[0]).apply(lambda x: x / x.sum()*100)
# Out:
#                               LoanStatusPercentage
# emp_length_range loan_status
# 0 years          0                       85.825200
#                  1                       14.174800
# 0-10 years       0                       86.031449
#                  1                       13.968551
# 10+ years        0                       84.319039
#                  1                       15.680961
# n/a              0                       77.928364
#                  1                       22.071636

# %%
#Derive the percentage of loans of each income verification status that default.
loan_emp_tenure = loanData.groupby(['verification_status','loan_status']).size().to_frame('LoanStatusPercentage')
loan_emp_tenure.groupby(level=[0]).apply(lambda x: x / x.sum()*100)
# Out:
#                                  LoanStatusPercentage
# verification_status loan_status
# Not Verified        0                       87.169043
#                     1                       12.830957
# Source Verified     0                       85.181358
#                     1                       14.818642
# Verified            0                       83.196788
#                     1                       16.803212

# %%
#Derive the percentage of loans of each purpose that default.
loan_emp_tenure = loanData.groupby(['purpose','loan_status']).size().to_frame('LoanStatusPercentage')
loan_emp_tenure.groupby(level=[0]).apply(lambda x: x / x.sum()*100)
# Out:
#                                 LoanStatusPercentage
# purpose            loan_status
# car                0                       89.326217
#                    1                       10.673783
# credit_card        0                       89.218222
#                    1                       10.781778
# debt_consolidation 0                       84.674605
#                    1                       15.325395
# educational        0                       82.769231
#                    1                       17.230769
# home_improvement   0                       87.930435
#                    1                       12.069565
# house              0                       83.923706
#                    1                       16.076294
# major_purchase     0                       89.674419
#                    1                       10.325581
# medical            0                       84.434655
#                    1                       15.565345
# moving             0                       84.027778
#                    1                       15.972222
# other              0                       83.622251
#                    1                       16.377749
# renewable_energy   0                       81.372549
#                    1                       18.627451
# small_business     0                       72.919042
#                    1                       27.080958
# vacation           0                       85.866667
#                    1                       14.133333
# wedding            0                       89.632829
#                    1                       10.367171

# %%
#Derive the percentage of loans of each type of home ownership that default.
loan_emp_tenure = loanData.groupby(['home_ownership','loan_status']).size().to_frame('LoanStatusPercentage')
loan_emp_tenure.groupby(level=[0]).apply(lambda x: x / x.sum()*100)
# Out:
#                             LoanStatusPercentage
# home_ownership loan_status
# MORTGAGE       0                       86.328653
#                1                       13.671347
# NONE           0                      100.000000
# OTHER          0                       81.632653
#                1                       18.367347
# OWN            0                       85.109244
#                1                       14.890756
# RENT           0                       84.637446
#                1                       15.362554

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'application_type', 'pub_rec_bankruptcies', 'emp_length_range'],
#       dtype='object')

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'application_type', 'pub_rec_bankruptcies', 'emp_length_range'],
#       dtype='object')

# %%
loanData_copy= loanData_defaulted.copy()

# %%
loanData_copy.corr()
# Out:
#                                id  member_id  loan_amnt  funded_amnt  \
# id                       1.000000   0.994192   0.153415     0.167022
# member_id                0.994192   1.000000   0.148485     0.161690
# loan_amnt                0.153415   0.148485   1.000000     0.979134
# funded_amnt              0.167022   0.161690   0.979134     1.000000
# funded_amnt_inv          0.310973   0.319364   0.907129     0.926996
# int_rate                 0.196032   0.197176   0.351216     0.353906
# installment              0.083107   0.071906   0.925911     0.953826
# annual_inc              -0.011801  -0.013352   0.352359     0.347131
# loan_status                   NaN        NaN        NaN          NaN
# dti                      0.111235   0.111183   0.063872     0.060861
# delinq_2yrs              0.002086   0.002918  -0.029843    -0.027366
# inq_last_6mths          -0.062355  -0.065406   0.007480     0.007942
# mths_since_last_delinq   0.111450   0.117480   0.012800     0.015370
# mths_since_last_record   0.677610   0.697226  -0.045680    -0.065083
# open_acc                 0.018655   0.012821   0.184323     0.181439
# pub_rec                 -0.042360  -0.039820  -0.047690    -0.052527
# revol_bal               -0.017684  -0.024654   0.313101     0.296956
# revol_util               0.106366   0.105831   0.042634     0.046757
# total_acc                0.032632   0.031458   0.283738     0.275088
# out_prncp                     NaN        NaN        NaN          NaN
# out_prncp_inv                 NaN        NaN        NaN          NaN
# total_pymnt              0.130110   0.127992   0.680814     0.698496
# total_pymnt_inv          0.221536   0.227669   0.643174     0.660695
# total_rec_prncp          0.054958   0.052423   0.551302     0.569719
# total_rec_int            0.208318   0.208931   0.699167     0.712395
# total_rec_late_fee      -0.093661  -0.096233   0.087517     0.094089
# recoveries               0.065405   0.062211   0.310185     0.316077
# collection_recovery_fee -0.050719  -0.054522   0.157602     0.164236
# last_pymnt_amnt          0.025868   0.021893   0.332981     0.338804
# pub_rec_bankruptcies    -0.026409  -0.022869  -0.028286    -0.033212
#
#                          funded_amnt_inv  int_rate  installment  annual_inc  \
# id                              0.310973  0.196032     0.083107   -0.011801
# member_id                       0.319364  0.197176     0.071906   -0.013352
# loan_amnt                       0.907129  0.351216     0.925911    0.352359
# funded_amnt                     0.926996  0.353906     0.953826    0.347131
# funded_amnt_inv                 1.000000  0.369863     0.858041    0.314505
# int_rate                        0.369863  1.000000     0.327909    0.132252
# installment                     0.858041  0.327909     1.000000    0.358656
# annual_inc                      0.314505  0.132252     0.358656    1.000000
# loan_status                          NaN       NaN          NaN         NaN
# dti                             0.072924  0.040607     0.042358   -0.089725
# delinq_2yrs                    -0.031524  0.119643    -0.012530    0.021765
# inq_last_6mths                 -0.018395  0.058475     0.018359    0.037303
# mths_since_last_delinq          0.084012 -0.015715    -0.008375   -0.024100
# mths_since_last_record          0.444677  0.354372    -0.149253   -0.058523
# open_acc                        0.154601  0.038607     0.179676    0.212320
# pub_rec                        -0.052717  0.079085    -0.041068   -0.006679
# revol_bal                       0.254045  0.075878     0.299930    0.379449
# revol_util                      0.065602  0.379245     0.074084    0.071373
# total_acc                       0.252796 -0.008655     0.251874    0.287343
# out_prncp                            NaN       NaN          NaN         NaN
# out_prncp_inv                        NaN       NaN          NaN         NaN
# total_pymnt                     0.685354  0.264457     0.666864    0.279975
# total_pymnt_inv                 0.726049  0.277016     0.616589    0.262635
# total_rec_prncp                 0.550112  0.070138     0.577424    0.239091
# total_rec_int                   0.718712  0.468654     0.628887    0.263186
# total_rec_late_fee              0.067972  0.055287     0.119871    0.062817
# recoveries                      0.301537  0.159769     0.300368    0.134942
# collection_recovery_fee         0.138645  0.072141     0.185040    0.087584
# last_pymnt_amnt                 0.291813  0.093077     0.350428    0.130603
# pub_rec_bankruptcies           -0.036099  0.074839    -0.025611   -0.004122
#
#                          loan_status       dti          ...           \
# id                               NaN  0.111235          ...
# member_id                        NaN  0.111183          ...
# loan_amnt                        NaN  0.063872          ...
# funded_amnt                      NaN  0.060861          ...
# funded_amnt_inv                  NaN  0.072924          ...
# int_rate                         NaN  0.040607          ...
# installment                      NaN  0.042358          ...
# annual_inc                       NaN -0.089725          ...
# loan_status                      NaN       NaN          ...
# dti                              NaN  1.000000          ...
# delinq_2yrs                      NaN -0.068839          ...
# inq_last_6mths                   NaN -0.028810          ...
# mths_since_last_delinq           NaN  0.075373          ...
# mths_since_last_record           NaN  0.179213          ...
# open_acc                         NaN  0.299230          ...
# pub_rec                          NaN  0.007990          ...
# revol_bal                        NaN  0.239712          ...
# revol_util                       NaN  0.227279          ...
# total_acc                        NaN  0.272802          ...
# out_prncp                        NaN       NaN          ...
# out_prncp_inv                    NaN       NaN          ...
# total_pymnt                      NaN  0.043360          ...
# total_pymnt_inv                  NaN  0.049070          ...
# total_rec_prncp                  NaN  0.014944          ...
# total_rec_int                    NaN  0.068741          ...
# total_rec_late_fee               NaN -0.037967          ...
# recoveries                       NaN  0.030623          ...
# collection_recovery_fee          NaN  0.006795          ...
# last_pymnt_amnt                  NaN  0.000367          ...
# pub_rec_bankruptcies             NaN  0.018904          ...
#
#                          out_prncp_inv  total_pymnt  total_pymnt_inv  \
# id                                 NaN     0.130110         0.221536
# member_id                          NaN     0.127992         0.227669
# loan_amnt                          NaN     0.680814         0.643174
# funded_amnt                        NaN     0.698496         0.660695
# funded_amnt_inv                    NaN     0.685354         0.726049
# int_rate                           NaN     0.264457         0.277016
# installment                        NaN     0.666864         0.616589
# annual_inc                         NaN     0.279975         0.262635
# loan_status                        NaN          NaN              NaN
# dti                                NaN     0.043360         0.049070
# delinq_2yrs                        NaN    -0.016056        -0.022492
# inq_last_6mths                     NaN    -0.045202        -0.056748
# mths_since_last_delinq             NaN     0.031953         0.077214
# mths_since_last_record             NaN    -0.090797         0.286926
# open_acc                           NaN     0.124532         0.111252
# pub_rec                            NaN    -0.041791        -0.042926
# revol_bal                          NaN     0.227425         0.203407
# revol_util                         NaN     0.068278         0.077162
# total_acc                          NaN     0.180439         0.169705
# out_prncp                          NaN          NaN              NaN
# out_prncp_inv                      NaN          NaN              NaN
# total_pymnt                        NaN     1.000000         0.968039
# total_pymnt_inv                    NaN     0.968039         1.000000
# total_rec_prncp                    NaN     0.914954         0.879115
# total_rec_int                      NaN     0.896605         0.885648
# total_rec_late_fee                 NaN     0.166237         0.140470
# recoveries                         NaN     0.406369         0.382478
# collection_recovery_fee            NaN     0.273131         0.237646
# last_pymnt_amnt                    NaN     0.261307         0.231893
# pub_rec_bankruptcies               NaN    -0.039709        -0.041418
#
#                          total_rec_prncp  total_rec_int  total_rec_late_fee  \
# id                              0.054958       0.208318           -0.093661
# member_id                       0.052423       0.208931           -0.096233
# loan_amnt                       0.551302       0.699167            0.087517
# funded_amnt                     0.569719       0.712395            0.094089
# funded_amnt_inv                 0.550112       0.718712            0.067972
# int_rate                        0.070138       0.468654            0.055287
# installment                     0.577424       0.628887            0.119871
# annual_inc                      0.239091       0.263186            0.062817
# loan_status                          NaN            NaN                 NaN
# dti                             0.014944       0.068741           -0.037967
# delinq_2yrs                    -0.034993       0.002871            0.029122
# inq_last_6mths                 -0.053692      -0.024286            0.017908
# mths_since_last_delinq          0.043404       0.033329           -0.023160
# mths_since_last_record         -0.178472       0.096135           -0.190312
# open_acc                        0.104110       0.124120           -0.022115
# pub_rec                        -0.034061      -0.019021           -0.038724
# revol_bal                       0.188357       0.215186            0.029719
# revol_util                      0.004808       0.136403            0.009150
# total_acc                       0.149291       0.176632           -0.022076
# out_prncp                            NaN            NaN                 NaN
# out_prncp_inv                        NaN            NaN                 NaN
# total_pymnt                     0.914954       0.896605            0.166237
# total_pymnt_inv                 0.879115       0.885648            0.140470
# total_rec_prncp                 1.000000       0.752971            0.150594
# total_rec_int                   0.752971       1.000000            0.143954
# total_rec_late_fee              0.150594       0.143954            1.000000
# recoveries                      0.096637       0.228767            0.071332
# collection_recovery_fee         0.049254       0.098505            0.092121
# last_pymnt_amnt                 0.276025       0.197087            0.105782
# pub_rec_bankruptcies           -0.037812      -0.012008           -0.040249
#
#                          recoveries  collection_recovery_fee  last_pymnt_amnt  \
# id                         0.065405                -0.050719         0.025868
# member_id                  0.062211                -0.054522         0.021893
# loan_amnt                  0.310185                 0.157602         0.332981
# funded_amnt                0.316077                 0.164236         0.338804
# funded_amnt_inv            0.301537                 0.138645         0.291813
# int_rate                   0.159769                 0.072141         0.093077
# installment                0.300368                 0.185040         0.350428
# annual_inc                 0.134942                 0.087584         0.130603
# loan_status                     NaN                      NaN              NaN
# dti                        0.030623                 0.006795         0.000367
# delinq_2yrs                0.014393                 0.024517        -0.000316
# inq_last_6mths            -0.014236                -0.005814         0.009718
# mths_since_last_delinq    -0.027332                -0.050234        -0.027472
# mths_since_last_record    -0.080410                -0.117284        -0.101281
# open_acc                   0.055083                 0.022238         0.057292
# pub_rec                   -0.053725                -0.036139        -0.024099
# revol_bal                  0.121192                 0.061735         0.124082
# revol_util                 0.049017                 0.018383         0.007930
# total_acc                  0.088087                 0.041615         0.089068
# out_prncp                       NaN                      NaN              NaN
# out_prncp_inv                   NaN                      NaN              NaN
# total_pymnt                0.406369                 0.273131         0.261307
# total_pymnt_inv            0.382478                 0.237646         0.231893
# total_rec_prncp            0.096637                 0.049254         0.276025
# total_rec_int              0.228767                 0.098505         0.197087
# total_rec_late_fee         0.071332                 0.092121         0.105782
# recoveries                 1.000000                 0.789900         0.075808
# collection_recovery_fee    0.789900                 1.000000         0.051925
# last_pymnt_amnt            0.075808                 0.051925         1.000000
# pub_rec_bankruptcies      -0.047837                -0.032899        -0.015146
#
#                          pub_rec_bankruptcies
# id                                  -0.026409
# member_id                           -0.022869
# loan_amnt                           -0.028286
# funded_amnt                         -0.033212
# funded_amnt_inv                     -0.036099
# int_rate                             0.074839
# installment                         -0.025611
# annual_inc                          -0.004122
# loan_status                               NaN
# dti                                  0.018904
# delinq_2yrs                          0.002453
# inq_last_6mths                       0.008612
# mths_since_last_delinq               0.056091
# mths_since_last_record               0.808997
# open_acc                             0.061357
# pub_rec                              0.863031
# revol_bal                           -0.050183
# revol_util                           0.065620
# total_acc                            0.031607
# out_prncp                                 NaN
# out_prncp_inv                             NaN
# total_pymnt                         -0.039709
# total_pymnt_inv                     -0.041418
# total_rec_prncp                     -0.037812
# total_rec_int                       -0.012008
# total_rec_late_fee                  -0.040249
# recoveries                          -0.047837
# collection_recovery_fee             -0.032899
# last_pymnt_amnt                     -0.015146
# pub_rec_bankruptcies                 1.000000
#
# [30 rows x 30 columns]

# %% [markdown]
# ### Correalation of Features

# %%
corr_attributes = ['annual_inc','grade','dti','sub_grade','emp_length_range','home_ownership','loan_status','purpose', 'addr_state', 'open_acc',
       'pub_rec', 'pub_rec_bankruptcies']

# %%
loandata_basic=loanData_copy.loc[:,corr_attributes]
loandata_basic.head()
# Out:
#     annual_inc grade    dti sub_grade emp_length_range home_ownership  \
# 1      30000.0     C   1.00        C4          0 years           RENT
# 8      40000.0     F   5.55        F2       0-10 years            OWN
# 9      15000.0     B  18.08        B5          0 years           RENT
# 12     30000.0     C  10.08        C1          0 years           RENT
# 14    100000.0     B   7.06        B2       0-10 years           RENT
#
#     loan_status             purpose addr_state  open_acc  pub_rec  \
# 1             1                 car         GA       3.0      0.0
# 8             1      small_business         CA      11.0      0.0
# 9             1               other         TX       2.0      0.0
# 12            1  debt_consolidation         VA       4.0      0.0
# 14            1               other         CA      14.0      0.0
#
#     pub_rec_bankruptcies
# 1                    0.0
# 8                    0.0
# 9                    0.0
# 12                   0.0
# 14                   0.0

# %%
labels = loandata_basic['grade'].astype('category').cat.categories.tolist()
replace_map_comp = {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}
loandata_basic['grade'] =loandata_basic['grade'].map(replace_map_comp)

# %%
sub_grade = loandata_basic['sub_grade'].astype('category').cat.categories.tolist()
replace_map_comp_sub_grade = {k: v for k,v in zip(sub_grade,list(range(1,len(sub_grade)+1)))}
loandata_basic['sub_grade'] =loandata_basic['sub_grade'].map(replace_map_comp_sub_grade)

# %%
purpose = loandata_basic['purpose'].astype('category').cat.categories.tolist()
replace_map_comp_purpose = {k: v for k,v in zip(purpose,list(range(1,len(purpose)+1)))}
loandata_basic['purpose'] =loandata_basic['purpose'].map(replace_map_comp_purpose)

# %%
addr_state = loandata_basic['addr_state'].astype('category').cat.categories.tolist()
replace_map_comp_addr_state = {k: v for k,v in zip(addr_state,list(range(1,len(addr_state)+1)))}
loandata_basic['addr_state'] =loandata_basic['addr_state'].map(replace_map_comp_addr_state)

# %%
home_ownership = loandata_basic['home_ownership'].astype('category').cat.categories.tolist()
replace_map_comp_home_ownership = {k: v for k,v in zip(home_ownership,list(range(1,len(home_ownership)+1)))}
loandata_basic['home_ownership'] =loandata_basic['home_ownership'].map(replace_map_comp_home_ownership)

# %%
loandata_basic.corr()
# Out:
#                       annual_inc     grade       dti  sub_grade  \
# annual_inc              1.000000  0.140372 -0.089725   0.141740
# grade                   0.140372  1.000000  0.022129   0.981481
# dti                    -0.089725  0.022129  1.000000   0.027835
# sub_grade               0.141740  0.981481  0.027835   1.000000
# home_ownership         -0.222419  0.002118 -0.027889   0.001091
# loan_status                  NaN       NaN       NaN        NaN
# purpose                 0.005439 -0.030061 -0.157800  -0.032818
# addr_state             -0.011682  0.015280  0.035130   0.020854
# open_acc                0.212320  0.036966  0.299230   0.041398
# pub_rec                -0.006679  0.086059  0.007990   0.088128
# pub_rec_bankruptcies   -0.004122  0.083163  0.018904   0.083494
#
#                       home_ownership  loan_status   purpose  addr_state  \
# annual_inc                 -0.222419          NaN  0.005439   -0.011682
# grade                       0.002118          NaN -0.030061    0.015280
# dti                        -0.027889          NaN -0.157800    0.035130
# sub_grade                   0.001091          NaN -0.032818    0.020854
# home_ownership              1.000000          NaN  0.056205   -0.054108
# loan_status                      NaN          NaN       NaN         NaN
# purpose                     0.056205          NaN  1.000000    0.012217
# addr_state                 -0.054108          NaN  0.012217    1.000000
# open_acc                   -0.222628          NaN -0.104983    0.032561
# pub_rec                    -0.036820          NaN -0.030365    0.000027
# pub_rec_bankruptcies       -0.040269          NaN -0.042273   -0.015798
#
#                       open_acc   pub_rec  pub_rec_bankruptcies
# annual_inc            0.212320 -0.006679             -0.004122
# grade                 0.036966  0.086059              0.083163
# dti                   0.299230  0.007990              0.018904
# sub_grade             0.041398  0.088128              0.083494
# home_ownership       -0.222628 -0.036820             -0.040269
# loan_status                NaN       NaN                   NaN
# purpose              -0.104983 -0.030365             -0.042273
# addr_state            0.032561  0.000027             -0.015798
# open_acc              1.000000  0.049776              0.061357
# pub_rec               0.049776  1.000000              0.863031
# pub_rec_bankruptcies  0.061357  0.863031              1.000000

# %%
plt.figure(figsize=(7,5))
sns.heatmap(data=loandata_basic.corr(), cmap="YlGnBu",fmt='g')

# %% [markdown]
# ### Bi-variate & Multivariate Analysis

# %% [markdown]
# ##### Grade Vs Loan status

# %%
loan_features = ['loan_status','grade','sub_grade','purpose','addr_state']

# %%
loan_features_df = pd.crosstab(columns=loanData.loan_status,index=loanData.grade)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
loan_features_df

#oan_features_df.columns[0].name="hai
loan_features_df.plot(kind='bar',figsize=(15,8))

# %% [markdown]
# #### Loan Status Vs Sub_grade

# %%
loan_features_df = pd.crosstab(columns=loanData.loan_status,index=loanData.sub_grade)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
loan_features_df

#oan_features_df.columns[0].name="hai
loan_features_df.plot(kind='bar',figsize=(15,8))

# %% [markdown]
# #### Loan Status Vs Purpose

# %%
loan_features_df = pd.crosstab(columns=loanData.loan_status,index=loanData.purpose)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
loan_features_df

#oan_features_df.columns[0].name="hai
loan_features_df.plot(kind='bar',figsize=(15,8))

# %% [markdown]
# #### Loan Status Vs Addr_state

# %%
loan_features_df = pd.crosstab(columns=loanData.loan_status,index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
loan_features_df.plot(kind='bar',figsize=(15,8))

# %% [markdown]
# #### finding the defaulter impact by state and grade

# %%
loan_features_df = pd.crosstab(columns=[loanData.loan_status,loanData.grade],index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
plt.figure(figsize=(10,15))
sns.heatmap(data=loan_features_df['Defaulter'],annot=True, cmap="YlGnBu",fmt='g')

# %% [markdown]
# ### finding the defaulter impact by state and Purpose

# %%
loan_features_df = pd.crosstab(columns=[loanData.loan_status,loanData.purpose],index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
plt.figure(figsize=(10,15))
sns.heatmap(data=loan_features_df['Defaulter'],annot=True, cmap="YlGnBu",fmt='g')

# %% [markdown]
# #### Defaulter by emp_lenght and State

# %%
loan_features_df = pd.crosstab(columns=[loanData.loan_status,loanData.emp_length_range],index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
plt.figure(figsize=(10,15))
sns.heatmap(data=loan_features_df['Defaulter'],annot=True, cmap="YlGnBu",fmt='g')

# %% [markdown]
# #### Defaulter by home_ownership and State

# %%
loan_features_df = pd.crosstab(columns=[loanData.loan_status,loanData.home_ownership],index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
plt.figure(figsize=(10,15))
sns.heatmap(data=loan_features_df['Defaulter'],annot=True, cmap="YlGnBu",fmt='g')

# %% [markdown]
# #### Defaulter by Public_rec and State

# %%
loan_features_df = pd.crosstab(columns=[loanData.loan_status,loanData.pub_rec],index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
plt.figure(figsize=(10,15))
sns.heatmap(data=loan_features_df['Defaulter'],annot=True, cmap="YlGnBu",fmt='g')

# %% [markdown]
# #### Defaulter by Public_rec and State

# %%
loan_features_df = pd.crosstab(columns=[loanData.loan_status,loanData.pub_rec_bankruptcies],index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
plt.figure(figsize=(10,15))
sns.heatmap(data=loan_features_df['Defaulter'],annot=True, cmap="YlGnBu",fmt='g')

# %% [markdown]
# <h1>Driving Factors for Risky customers</h1>
#  <li>annual_inc</li><li>grade</li><li>dti</li><li>sub_grade</li><li>emp_length_range</li><li>home_ownership</li><li>loan_status</li><li>purpose</li><li>addr_state</li><li>open_acc</li><li>pub_rec</li><li>pub_rec_bankruptcies</li>
