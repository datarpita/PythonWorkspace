# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import zipfile

# %% [markdown]
# ### Loading the data

# %%
zf = zipfile.ZipFile('loan.zip')

# %%
date_mon_yy = lambda x: pd.datetime.strptime(x, '%d-%B-%y')

# %%
loans_df = pd.read_csv(zf.open(zipfile.ZipFile.namelist(zf)[0]),parse_dates=True)
# Out:
# C:\Users\bgurusam\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(loans_df.columns)
# Out:
# 111

# %%
loans_df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# 50%        8975.000000    280.220000  5.900000e+04     13.400000
# 75%       14400.000000    430.780000  8.230000e+04     18.600000
# max       35000.000000   1305.190000  6.000000e+06     29.990000
#
#         delinq_2yrs  inq_last_6mths             ...              \
# count  39717.000000    39717.000000             ...
# mean       0.146512        0.869200             ...
# std        0.491812        1.070219             ...
# min        0.000000        0.000000             ...
# 25%        0.000000        0.000000             ...
# 50%        0.000000        1.000000             ...
# 75%        0.000000        1.000000             ...
# max       11.000000        8.000000             ...
#
#        num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# count                 0.0                 0.0             0.0
# mean                  NaN                 NaN             NaN
# std                   NaN                 NaN             NaN
# min                   NaN                 NaN             NaN
# 25%                   NaN                 NaN             NaN
# 50%                   NaN                 NaN             NaN
# 75%                   NaN                 NaN             NaN
# max                   NaN                 NaN             NaN
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# count               0.0          39020.000000    39678.0              0.0
# mean                NaN              0.043260        0.0              NaN
# std                 NaN              0.204324        0.0              NaN
# min                 NaN              0.000000        0.0              NaN
# 25%                 NaN              0.000000        0.0              NaN
# 50%                 NaN              0.000000        0.0              NaN
# 75%                 NaN              0.000000        0.0              NaN
# max                 NaN              2.000000        0.0              NaN
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# count                0.0             0.0                         0.0
# mean                 NaN             NaN                         NaN
# std                  NaN             NaN                         NaN
# min                  NaN             NaN                         NaN
# 25%                  NaN             NaN                         NaN
# 50%                  NaN             NaN                         NaN
# 75%                  NaN             NaN                         NaN
# max                  NaN             NaN                         NaN
#
# [8 rows x 87 columns]

# %%
total_rows = loans_df.shape[0]

# %% [markdown]
# ### % of missing fields

# %%
round((loans_df.isna().sum()/total_rows)*100,2)
# Out:
# id                                  0.00
# member_id                           0.00
# loan_amnt                           0.00
# funded_amnt                         0.00
# funded_amnt_inv                     0.00
# term                                0.00
# int_rate                            0.00
# installment                         0.00
# grade                               0.00
# sub_grade                           0.00
# emp_title                           6.19
# emp_length                          2.71
# home_ownership                      0.00
# annual_inc                          0.00
# verification_status                 0.00
# issue_d                             0.00
# loan_status                         0.00
# pymnt_plan                          0.00
# url                                 0.00
# desc                               32.58
# purpose                             0.00
# title                               0.03
# zip_code                            0.00
# addr_state                          0.00
# dti                                 0.00
# delinq_2yrs                         0.00
# earliest_cr_line                    0.00
# inq_last_6mths                      0.00
# mths_since_last_delinq             64.66
# mths_since_last_record             92.99
#                                    ...
# mo_sin_old_rev_tl_op              100.00
# mo_sin_rcnt_rev_tl_op             100.00
# mo_sin_rcnt_tl                    100.00
# mort_acc                          100.00
# mths_since_recent_bc              100.00
# mths_since_recent_bc_dlq          100.00
# mths_since_recent_inq             100.00
# mths_since_recent_revol_delinq    100.00
# num_accts_ever_120_pd             100.00
# num_actv_bc_tl                    100.00
# num_actv_rev_tl                   100.00
# num_bc_sats                       100.00
# num_bc_tl                         100.00
# num_il_tl                         100.00
# num_op_rev_tl                     100.00
# num_rev_accts                     100.00
# num_rev_tl_bal_gt_0               100.00
# num_sats                          100.00
# num_tl_120dpd_2m                  100.00
# num_tl_30dpd                      100.00
# num_tl_90g_dpd_24m                100.00
# num_tl_op_past_12m                100.00
# pct_tl_nvr_dlq                    100.00
# percent_bc_gt_75                  100.00
# pub_rec_bankruptcies                1.75
# tax_liens                           0.10
# tot_hi_cred_lim                   100.00
# total_bal_ex_mort                 100.00
# total_bc_limit                    100.00
# total_il_high_credit_limit        100.00
# Length: 111, dtype: float64

# %% [markdown]
# ### Removing the columns whose values are null

# %%
loans_df1 = loans_df.dropna(axis=1,how='all')

# %% [markdown]
# #### after removing null columns finally we got 57 columns

# %%
len(loans_df1.columns)
# Out:
# 57

# %%
round((loans_df1.isna().sum()/loans_df1.shape[0])*100,2)
# Out:
# id                             0.00
# member_id                      0.00
# loan_amnt                      0.00
# funded_amnt                    0.00
# funded_amnt_inv                0.00
# term                           0.00
# int_rate                       0.00
# installment                    0.00
# grade                          0.00
# sub_grade                      0.00
# emp_title                      6.19
# emp_length                     2.71
# home_ownership                 0.00
# annual_inc                     0.00
# verification_status            0.00
# issue_d                        0.00
# loan_status                    0.00
# pymnt_plan                     0.00
# url                            0.00
# desc                          32.58
# purpose                        0.00
# title                          0.03
# zip_code                       0.00
# addr_state                     0.00
# dti                            0.00
# delinq_2yrs                    0.00
# earliest_cr_line               0.00
# inq_last_6mths                 0.00
# mths_since_last_delinq        64.66
# mths_since_last_record        92.99
# open_acc                       0.00
# pub_rec                        0.00
# revol_bal                      0.00
# revol_util                     0.13
# total_acc                      0.00
# initial_list_status            0.00
# out_prncp                      0.00
# out_prncp_inv                  0.00
# total_pymnt                    0.00
# total_pymnt_inv                0.00
# total_rec_prncp                0.00
# total_rec_int                  0.00
# total_rec_late_fee             0.00
# recoveries                     0.00
# collection_recovery_fee        0.00
# last_pymnt_d                   0.18
# last_pymnt_amnt                0.00
# next_pymnt_d                  97.13
# last_credit_pull_d             0.01
# collections_12_mths_ex_med     0.14
# policy_code                    0.00
# application_type               0.00
# acc_now_delinq                 0.00
# chargeoff_within_12_mths       0.14
# delinq_amnt                    0.00
# pub_rec_bankruptcies           1.75
# tax_liens                      0.10
# dtype: float64

# %% [markdown]
# ### next_pyment_d is 97% empty

# %%
loans_df1.next_pymnt_d.value_counts()
# Out:
# Jun-16    1125
# Jul-16      15
# Name: next_pymnt_d, dtype: int64

# %% [markdown]
# ### Next payment (upcomming) column doesnt need so droping off.

# %%
loans_df1.drop(columns='next_pymnt_d',axis=1,inplace=True)
len(loans_df1.columns)
# Out:
# C:\Users\bgurusam\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# 56

# %%
round((loans_df1.isna().sum()/loans_df1.shape[0])*100,2)
# Out:
# id                             0.00
# member_id                      0.00
# loan_amnt                      0.00
# funded_amnt                    0.00
# funded_amnt_inv                0.00
# term                           0.00
# int_rate                       0.00
# installment                    0.00
# grade                          0.00
# sub_grade                      0.00
# emp_title                      6.19
# emp_length                     2.71
# home_ownership                 0.00
# annual_inc                     0.00
# verification_status            0.00
# issue_d                        0.00
# loan_status                    0.00
# pymnt_plan                     0.00
# url                            0.00
# desc                          32.58
# purpose                        0.00
# title                          0.03
# zip_code                       0.00
# addr_state                     0.00
# dti                            0.00
# delinq_2yrs                    0.00
# earliest_cr_line               0.00
# inq_last_6mths                 0.00
# mths_since_last_delinq        64.66
# mths_since_last_record        92.99
# open_acc                       0.00
# pub_rec                        0.00
# revol_bal                      0.00
# revol_util                     0.13
# total_acc                      0.00
# initial_list_status            0.00
# out_prncp                      0.00
# out_prncp_inv                  0.00
# total_pymnt                    0.00
# total_pymnt_inv                0.00
# total_rec_prncp                0.00
# total_rec_int                  0.00
# total_rec_late_fee             0.00
# recoveries                     0.00
# collection_recovery_fee        0.00
# last_pymnt_d                   0.18
# last_pymnt_amnt                0.00
# last_credit_pull_d             0.01
# collections_12_mths_ex_med     0.14
# policy_code                    0.00
# application_type               0.00
# acc_now_delinq                 0.00
# chargeoff_within_12_mths       0.14
# delinq_amnt                    0.00
# pub_rec_bankruptcies           1.75
# tax_liens                      0.10
# dtype: float64

# %%
loans_df1['revol_util'].head()
# Out:
# 0    83.70%
# 1     9.40%
# 2    98.50%
# 3       21%
# 4    53.90%
# Name: revol_util, dtype: object

# %%
loans_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 56 columns):
# id                            39717 non-null int64
# member_id                     39717 non-null int64
# loan_amnt                     39717 non-null int64
# funded_amnt                   39717 non-null int64
# funded_amnt_inv               39717 non-null float64
# term                          39717 non-null object
# int_rate                      39717 non-null object
# installment                   39717 non-null float64
# grade                         39717 non-null object
# sub_grade                     39717 non-null object
# emp_title                     37258 non-null object
# emp_length                    38642 non-null object
# home_ownership                39717 non-null object
# annual_inc                    39717 non-null float64
# verification_status           39717 non-null object
# issue_d                       39717 non-null object
# loan_status                   39717 non-null object
# pymnt_plan                    39717 non-null object
# url                           39717 non-null object
# desc                          26777 non-null object
# purpose                       39717 non-null object
# title                         39706 non-null object
# zip_code                      39717 non-null object
# addr_state                    39717 non-null object
# dti                           39717 non-null float64
# delinq_2yrs                   39717 non-null int64
# earliest_cr_line              39717 non-null object
# inq_last_6mths                39717 non-null int64
# mths_since_last_delinq        14035 non-null float64
# mths_since_last_record        2786 non-null float64
# open_acc                      39717 non-null int64
# pub_rec                       39717 non-null int64
# revol_bal                     39717 non-null int64
# revol_util                    39667 non-null object
# total_acc                     39717 non-null int64
# initial_list_status           39717 non-null object
# out_prncp                     39717 non-null float64
# out_prncp_inv                 39717 non-null float64
# total_pymnt                   39717 non-null float64
# total_pymnt_inv               39717 non-null float64
# total_rec_prncp               39717 non-null float64
# total_rec_int                 39717 non-null float64
# total_rec_late_fee            39717 non-null float64
# recoveries                    39717 non-null float64
# collection_recovery_fee       39717 non-null float64
# last_pymnt_d                  39646 non-null object
# last_pymnt_amnt               39717 non-null float64
# last_credit_pull_d            39715 non-null object
# collections_12_mths_ex_med    39661 non-null float64
# policy_code                   39717 non-null int64
# application_type              39717 non-null object
# acc_now_delinq                39717 non-null int64
# chargeoff_within_12_mths      39661 non-null float64
# delinq_amnt                   39717 non-null int64
# pub_rec_bankruptcies          39020 non-null float64
# tax_liens                     39678 non-null float64
# dtypes: float64(20), int64(13), object(23)
# memory usage: 17.0+ MB

# %%
loans_df1.loc['revol_util'] =loans_df1.revol_util.apply(lambda x: float(str(x).replace('%','')))
# Out:
# C:\Users\bgurusam\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
loans_df1.loc['term'] =loans_df1.term.apply(lambda x: str(x).replace('months','').strip())
# Out:
# C:\Users\bgurusam\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Catagerical column: 'emp_length' re-arranging to range as per definition

# %%
loans_df1.emp_length.value_counts()/total_rows
# Out:
# 10+ years    0.223557
# < 1 year     0.115391
# 2 years      0.110482
# 3 years      0.103104
# 4 years      0.086512
# 5 years      0.082635
# 1 year       0.081577
# 6 years      0.056122
# 7 years      0.044641
# 8 years      0.037238
# 9 years      0.031674
# Name: emp_length, dtype: float64

# %%
loans_df1.emp_length.unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %% [markdown]
# ### Creating dict for emp_length

# %%
## 0-1, 1-9,10+, na
## corr the title company..... revisit
emp_len_dict = {k:'0-10 years' for k in loans_df1.emp_length.unique()}
emp_len_dict['n/a']='n/a'
emp_len_dict['10+ years'] = '10+ years'
emp_len_dict['< 1 year']='0 years'


print(emp_len_dict)
# Out:
# {'10+ years': '10+ years', '< 1 year': '0 years', '1 year': '0-10 years', '3 years': '0-10 years', '8 years': '0-10 years', '9 years': '0-10 years', '4 years': '0-10 years', '5 years': '0-10 years', '6 years': '0-10 years', '2 years': '0-10 years', '7 years': '0-10 years', nan: '0-10 years', 'n/a': 'n/a'}

# %% [markdown]
# ### Replacing nan to 'n/a' for emp_length

# %%
loans_df1.emp_length.fillna('n/a',inplace=True,axis=0)
# Out:
# C:\Users\bgurusam\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
loans_df1['emp_length_range'] = loans_df1.emp_length.map(emp_len_dict)
# Out:
# C:\Users\bgurusam\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
loans_df1['emp_length_range'].unique()
# Out:
# array(['10+ years', '0 years', '0-10 years', 'n/a'], dtype=object)

# %%
(loans_df1.emp_length_range.value_counts()/total_rows)*100
# Out:
# 0-10 years    63.398545
# 10+ years     22.355666
# 0 years       11.539139
# n/a            2.711685
# Name: emp_length_range, dtype: float64

# %% [markdown]
# #### from above emp_lenght % , n/a is 2% of total row's. so it can ignore

# %%
loanData = loans_df1.copy()

# %%
loanData.drop(columns=['url'],axis=1,inplace=True)

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt',
#        'pub_rec_bankruptcies', 'tax_liens', 'emp_length_range'],
#       dtype='object')

# %% [markdown]
# ### convert to date

# %%
col_date =['issue_d','last_pymnt_d','last_credit_pull_d']

# %%
loanData['issue_d'].head(20)
# Out:
# 0     Dec-11
# 1     Dec-11
# 2     Dec-11
# 3     Dec-11
# 4     Dec-11
# 5     Dec-11
# 6     Dec-11
# 7     Dec-11
# 8     Dec-11
# 9     Dec-11
# 10    Dec-11
# 11    Dec-11
# 12    Dec-11
# 13    Dec-11
# 14    Dec-11
# 15    Dec-11
# 16    Dec-11
# 17    Dec-11
# 18    Dec-11
# 19    Dec-11
# Name: issue_d, dtype: object

# %%
loanData['issue_d'] = pd.to_datetime(loanData['issue_d'],format='%b-%y')

# %%
loanData.corr()
# Out:
#                                   id  member_id  loan_amnt  funded_amnt  \
# id                          1.000000   0.993650   0.141919     0.152286
# member_id                   0.993650   1.000000   0.140710     0.150322
# loan_amnt                   0.141919   0.140710   1.000000     0.981578
# funded_amnt                 0.152286   0.150322   0.981578     1.000000
# funded_amnt_inv             0.249547   0.257887   0.940034     0.958422
# installment                 0.086587   0.081025   0.930288     0.956159
# annual_inc                  0.008731   0.009380   0.271149     0.266965
# dti                         0.095983   0.096963   0.066439     0.066283
# delinq_2yrs                -0.008644  -0.008119  -0.031864    -0.032355
# inq_last_6mths             -0.042378  -0.047086   0.009229     0.009259
# mths_since_last_delinq      0.117193   0.122963   0.014871     0.016359
# mths_since_last_record      0.702130   0.719538   0.004968    -0.006059
# open_acc                    0.020388   0.017928   0.177168     0.175530
# pub_rec                    -0.019440  -0.018721  -0.051236    -0.052169
# revol_bal                   0.008763   0.005113   0.317597     0.310392
# total_acc                   0.042149   0.044374   0.256442     0.250589
# out_prncp                   0.180619   0.170743   0.192937     0.194941
# out_prncp_inv               0.180591   0.170706   0.192623     0.194675
# total_pymnt                 0.140045   0.139975   0.886613     0.903160
# total_pymnt_inv             0.220838   0.229307   0.854243     0.870799
# total_rec_prncp             0.112213   0.112168   0.852021     0.870255
# total_rec_int               0.172856   0.173234   0.729726     0.737469
# total_rec_late_fee         -0.055082  -0.057750   0.044706     0.046705
# recoveries                  0.033426   0.031565   0.135446     0.136284
# collection_recovery_fee    -0.013359  -0.015155   0.072853     0.074676
# last_pymnt_amnt             0.122365   0.123627   0.448742     0.453133
# collections_12_mths_ex_med       NaN        NaN        NaN          NaN
# policy_code                      NaN        NaN        NaN          NaN
# acc_now_delinq                   NaN        NaN        NaN          NaN
# chargeoff_within_12_mths         NaN        NaN        NaN          NaN
# delinq_amnt                      NaN        NaN        NaN          NaN
# pub_rec_bankruptcies       -0.009505  -0.008769  -0.037180    -0.038502
# tax_liens                        NaN        NaN        NaN          NaN
#
#                             funded_amnt_inv  installment  annual_inc  \
# id                                 0.249547     0.086587    0.008731
# member_id                          0.257887     0.081025    0.009380
# loan_amnt                          0.940034     0.930288    0.271149
# funded_amnt                        0.958422     0.956159    0.266965
# funded_amnt_inv                    1.000000     0.905039    0.254375
# installment                        0.905039     1.000000    0.270874
# annual_inc                         0.254375     0.270874    1.000000
# dti                                0.074689     0.054186   -0.122732
# delinq_2yrs                       -0.038501    -0.019657    0.023083
# inq_last_6mths                    -0.005712     0.009722    0.033908
# mths_since_last_delinq             0.071924     0.000047   -0.008822
# mths_since_last_record             0.437906    -0.062171   -0.031866
# open_acc                           0.163027     0.172812    0.158200
# pub_rec                           -0.053214    -0.046532   -0.018689
# revol_bal                          0.290797     0.312679    0.279961
# total_acc                          0.242854     0.230824    0.235771
# out_prncp                          0.203688     0.125082    0.033573
# out_prncp_inv                      0.203693     0.124932    0.033472
# total_pymnt                        0.881228     0.856928    0.257980
# total_pymnt_inv                    0.913257     0.817416    0.247119
# total_rec_prncp                    0.845848     0.850773    0.259571
# total_rec_int                      0.730914     0.634725    0.185476
# total_rec_late_fee                 0.027172     0.056709    0.006243
# recoveries                         0.123759     0.118152    0.021589
# collection_recovery_fee            0.060358     0.075467    0.015604
# last_pymnt_amnt                    0.442604     0.401688    0.140401
# collections_12_mths_ex_med              NaN          NaN         NaN
# policy_code                             NaN          NaN         NaN
# acc_now_delinq                          NaN          NaN         NaN
# chargeoff_within_12_mths                NaN          NaN         NaN
# delinq_amnt                             NaN          NaN         NaN
# pub_rec_bankruptcies              -0.042746    -0.034103   -0.016801
# tax_liens                               NaN          NaN         NaN
#
#                                  dti  delinq_2yrs  inq_last_6mths    ...      \
# id                          0.095983    -0.008644       -0.042378    ...
# member_id                   0.096963    -0.008119       -0.047086    ...
# loan_amnt                   0.066439    -0.031864        0.009229    ...
# funded_amnt                 0.066283    -0.032355        0.009259    ...
# funded_amnt_inv             0.074689    -0.038501       -0.005712    ...
# installment                 0.054186    -0.019657        0.009722    ...
# annual_inc                 -0.122732     0.023083        0.033908    ...
# dti                         1.000000    -0.034452        0.001405    ...
# delinq_2yrs                -0.034452     1.000000        0.008091    ...
# inq_last_6mths              0.001405     0.008091        1.000000    ...
# mths_since_last_delinq      0.068815    -0.569438       -0.003851    ...
# mths_since_last_record      0.187175    -0.036628       -0.027878    ...
# open_acc                    0.288045     0.011656        0.091713    ...
# pub_rec                    -0.004621     0.007463        0.024802    ...
# revol_bal                   0.228743    -0.055125       -0.022381    ...
# total_acc                   0.229881     0.067892        0.111499    ...
# out_prncp                   0.036095    -0.003008       -0.012106    ...
# out_prncp_inv               0.036012    -0.003203       -0.011780    ...
# total_pymnt                 0.064766    -0.022695       -0.010559    ...
# total_pymnt_inv             0.071647    -0.028976       -0.020277    ...
# total_rec_prncp             0.041316    -0.038795       -0.023433    ...
# total_rec_int               0.106071     0.023077        0.021774    ...
# total_rec_late_fee         -0.011781     0.030609        0.031215    ...
# recoveries                  0.024878     0.012315        0.018972    ...
# collection_recovery_fee     0.011033     0.013912        0.012420    ...
# last_pymnt_amnt             0.005212    -0.012149        0.028514    ...
# collections_12_mths_ex_med       NaN          NaN             NaN    ...
# policy_code                      NaN          NaN             NaN    ...
# acc_now_delinq                   NaN          NaN             NaN    ...
# chargeoff_within_12_mths         NaN          NaN             NaN    ...
# delinq_amnt                      NaN          NaN             NaN    ...
# pub_rec_bankruptcies        0.005691     0.003375        0.016346    ...
# tax_liens                        NaN          NaN             NaN    ...
#
#                             recoveries  collection_recovery_fee  \
# id                            0.033426                -0.013359
# member_id                     0.031565                -0.015155
# loan_amnt                     0.135446                 0.072853
# funded_amnt                   0.136284                 0.074676
# funded_amnt_inv               0.123759                 0.060358
# installment                   0.118152                 0.075467
# annual_inc                    0.021589                 0.015604
# dti                           0.024878                 0.011033
# delinq_2yrs                   0.012315                 0.013912
# inq_last_6mths                0.018972                 0.012420
# mths_since_last_delinq       -0.008622                -0.018697
# mths_since_last_record       -0.013125                -0.038484
# open_acc                      0.016396                 0.006219
# pub_rec                      -0.005521                -0.005536
# revol_bal                     0.042091                 0.022400
# total_acc                     0.023281                 0.010551
# out_prncp                    -0.018878                -0.011394
# out_prncp_inv                -0.018858                -0.011382
# total_pymnt                   0.023950                 0.024555
# total_pymnt_inv               0.017862                 0.015016
# total_rec_prncp              -0.094821                -0.058634
# total_rec_int                 0.075552                 0.033289
# total_rec_late_fee            0.099925                 0.093178
# recoveries                    1.000000                 0.796816
# collection_recovery_fee       0.796816                 1.000000
# last_pymnt_amnt              -0.069955                -0.041874
# collections_12_mths_ex_med         NaN                      NaN
# policy_code                        NaN                      NaN
# acc_now_delinq                     NaN                      NaN
# chargeoff_within_12_mths           NaN                      NaN
# delinq_amnt                        NaN                      NaN
# pub_rec_bankruptcies         -0.004651                -0.005208
# tax_liens                          NaN                      NaN
#
#                             last_pymnt_amnt  collections_12_mths_ex_med  \
# id                                 0.122365                         NaN
# member_id                          0.123627                         NaN
# loan_amnt                          0.448742                         NaN
# funded_amnt                        0.453133                         NaN
# funded_amnt_inv                    0.442604                         NaN
# installment                        0.401688                         NaN
# annual_inc                         0.140401                         NaN
# dti                                0.005212                         NaN
# delinq_2yrs                       -0.012149                         NaN
# inq_last_6mths                     0.028514                         NaN
# mths_since_last_delinq             0.007023                         NaN
# mths_since_last_record             0.078624                         NaN
# open_acc                           0.078865                         NaN
# pub_rec                           -0.032214                         NaN
# revol_bal                          0.120371                         NaN
# total_acc                          0.162841                         NaN
# out_prncp                         -0.066393                         NaN
# out_prncp_inv                     -0.066324                         NaN
# total_pymnt                        0.474624                         NaN
# total_pymnt_inv                    0.462255                         NaN
# total_rec_prncp                    0.543408                         NaN
# total_rec_int                      0.191990                         NaN
# total_rec_late_fee                -0.060600                         NaN
# recoveries                        -0.069955                         NaN
# collection_recovery_fee           -0.041874                         NaN
# last_pymnt_amnt                    1.000000                         NaN
# collections_12_mths_ex_med              NaN                         NaN
# policy_code                             NaN                         NaN
# acc_now_delinq                          NaN                         NaN
# chargeoff_within_12_mths                NaN                         NaN
# delinq_amnt                             NaN                         NaN
# pub_rec_bankruptcies              -0.022585                         NaN
# tax_liens                               NaN                         NaN
#
#                             policy_code  acc_now_delinq  \
# id                                  NaN             NaN
# member_id                           NaN             NaN
# loan_amnt                           NaN             NaN
# funded_amnt                         NaN             NaN
# funded_amnt_inv                     NaN             NaN
# installment                         NaN             NaN
# annual_inc                          NaN             NaN
# dti                                 NaN             NaN
# delinq_2yrs                         NaN             NaN
# inq_last_6mths                      NaN             NaN
# mths_since_last_delinq              NaN             NaN
# mths_since_last_record              NaN             NaN
# open_acc                            NaN             NaN
# pub_rec                             NaN             NaN
# revol_bal                           NaN             NaN
# total_acc                           NaN             NaN
# out_prncp                           NaN             NaN
# out_prncp_inv                       NaN             NaN
# total_pymnt                         NaN             NaN
# total_pymnt_inv                     NaN             NaN
# total_rec_prncp                     NaN             NaN
# total_rec_int                       NaN             NaN
# total_rec_late_fee                  NaN             NaN
# recoveries                          NaN             NaN
# collection_recovery_fee             NaN             NaN
# last_pymnt_amnt                     NaN             NaN
# collections_12_mths_ex_med          NaN             NaN
# policy_code                         NaN             NaN
# acc_now_delinq                      NaN             NaN
# chargeoff_within_12_mths            NaN             NaN
# delinq_amnt                         NaN             NaN
# pub_rec_bankruptcies                NaN             NaN
# tax_liens                           NaN             NaN
#
#                             chargeoff_within_12_mths  delinq_amnt  \
# id                                               NaN          NaN
# member_id                                        NaN          NaN
# loan_amnt                                        NaN          NaN
# funded_amnt                                      NaN          NaN
# funded_amnt_inv                                  NaN          NaN
# installment                                      NaN          NaN
# annual_inc                                       NaN          NaN
# dti                                              NaN          NaN
# delinq_2yrs                                      NaN          NaN
# inq_last_6mths                                   NaN          NaN
# mths_since_last_delinq                           NaN          NaN
# mths_since_last_record                           NaN          NaN
# open_acc                                         NaN          NaN
# pub_rec                                          NaN          NaN
# revol_bal                                        NaN          NaN
# total_acc                                        NaN          NaN
# out_prncp                                        NaN          NaN
# out_prncp_inv                                    NaN          NaN
# total_pymnt                                      NaN          NaN
# total_pymnt_inv                                  NaN          NaN
# total_rec_prncp                                  NaN          NaN
# total_rec_int                                    NaN          NaN
# total_rec_late_fee                               NaN          NaN
# recoveries                                       NaN          NaN
# collection_recovery_fee                          NaN          NaN
# last_pymnt_amnt                                  NaN          NaN
# collections_12_mths_ex_med                       NaN          NaN
# policy_code                                      NaN          NaN
# acc_now_delinq                                   NaN          NaN
# chargeoff_within_12_mths                         NaN          NaN
# delinq_amnt                                      NaN          NaN
# pub_rec_bankruptcies                             NaN          NaN
# tax_liens                                        NaN          NaN
#
#                             pub_rec_bankruptcies  tax_liens
# id                                     -0.009505        NaN
# member_id                              -0.008769        NaN
# loan_amnt                              -0.037180        NaN
# funded_amnt                            -0.038502        NaN
# funded_amnt_inv                        -0.042746        NaN
# installment                            -0.034103        NaN
# annual_inc                             -0.016801        NaN
# dti                                     0.005691        NaN
# delinq_2yrs                             0.003375        NaN
# inq_last_6mths                          0.016346        NaN
# mths_since_last_delinq                  0.025841        NaN
# mths_since_last_record                  0.823352        NaN
# open_acc                                0.005930        NaN
# pub_rec                                 0.847305        NaN
# revol_bal                              -0.049406        NaN
# total_acc                              -0.011807        NaN
# out_prncp                              -0.010024        NaN
# out_prncp_inv                          -0.010314        NaN
# total_pymnt                            -0.043661        NaN
# total_pymnt_inv                        -0.047011        NaN
# total_rec_prncp                        -0.054125        NaN
# total_rec_int                          -0.003609        NaN
# total_rec_late_fee                     -0.005489        NaN
# recoveries                             -0.004651        NaN
# collection_recovery_fee                -0.005208        NaN
# last_pymnt_amnt                        -0.022585        NaN
# collections_12_mths_ex_med                   NaN        NaN
# policy_code                                  NaN        NaN
# acc_now_delinq                               NaN        NaN
# chargeoff_within_12_mths                     NaN        NaN
# delinq_amnt                                  NaN        NaN
# pub_rec_bankruptcies                    1.000000        NaN
# tax_liens                                    NaN        NaN
#
# [33 rows x 33 columns]

# %%
loanData.drop(columns=['tax_liens','delinq_amnt','chargeoff_within_12_mths','acc_now_delinq','policy_code','collections_12_mths_ex_med'],axis=1,inplace=True)

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'application_type', 'pub_rec_bankruptcies', 'emp_length_range'],
#       dtype='object')

# %%
loanData.corr()
# Out:
#                                id  member_id  loan_amnt  funded_amnt  \
# id                       1.000000   0.993650   0.141919     0.152286
# member_id                0.993650   1.000000   0.140710     0.150322
# loan_amnt                0.141919   0.140710   1.000000     0.981578
# funded_amnt              0.152286   0.150322   0.981578     1.000000
# funded_amnt_inv          0.249547   0.257887   0.940034     0.958422
# installment              0.086587   0.081025   0.930288     0.956159
# annual_inc               0.008731   0.009380   0.271149     0.266965
# dti                      0.095983   0.096963   0.066439     0.066283
# delinq_2yrs             -0.008644  -0.008119  -0.031864    -0.032355
# inq_last_6mths          -0.042378  -0.047086   0.009229     0.009259
# mths_since_last_delinq   0.117193   0.122963   0.014871     0.016359
# mths_since_last_record   0.702130   0.719538   0.004968    -0.006059
# open_acc                 0.020388   0.017928   0.177168     0.175530
# pub_rec                 -0.019440  -0.018721  -0.051236    -0.052169
# revol_bal                0.008763   0.005113   0.317597     0.310392
# total_acc                0.042149   0.044374   0.256442     0.250589
# out_prncp                0.180619   0.170743   0.192937     0.194941
# out_prncp_inv            0.180591   0.170706   0.192623     0.194675
# total_pymnt              0.140045   0.139975   0.886613     0.903160
# total_pymnt_inv          0.220838   0.229307   0.854243     0.870799
# total_rec_prncp          0.112213   0.112168   0.852021     0.870255
# total_rec_int            0.172856   0.173234   0.729726     0.737469
# total_rec_late_fee      -0.055082  -0.057750   0.044706     0.046705
# recoveries               0.033426   0.031565   0.135446     0.136284
# collection_recovery_fee -0.013359  -0.015155   0.072853     0.074676
# last_pymnt_amnt          0.122365   0.123627   0.448742     0.453133
# pub_rec_bankruptcies    -0.009505  -0.008769  -0.037180    -0.038502
#
#                          funded_amnt_inv  installment  annual_inc       dti  \
# id                              0.249547     0.086587    0.008731  0.095983
# member_id                       0.257887     0.081025    0.009380  0.096963
# loan_amnt                       0.940034     0.930288    0.271149  0.066439
# funded_amnt                     0.958422     0.956159    0.266965  0.066283
# funded_amnt_inv                 1.000000     0.905039    0.254375  0.074689
# installment                     0.905039     1.000000    0.270874  0.054186
# annual_inc                      0.254375     0.270874    1.000000 -0.122732
# dti                             0.074689     0.054186   -0.122732  1.000000
# delinq_2yrs                    -0.038501    -0.019657    0.023083 -0.034452
# inq_last_6mths                 -0.005712     0.009722    0.033908  0.001405
# mths_since_last_delinq          0.071924     0.000047   -0.008822  0.068815
# mths_since_last_record          0.437906    -0.062171   -0.031866  0.187175
# open_acc                        0.163027     0.172812    0.158200  0.288045
# pub_rec                        -0.053214    -0.046532   -0.018689 -0.004621
# revol_bal                       0.290797     0.312679    0.279961  0.228743
# total_acc                       0.242854     0.230824    0.235771  0.229881
# out_prncp                       0.203688     0.125082    0.033573  0.036095
# out_prncp_inv                   0.203693     0.124932    0.033472  0.036012
# total_pymnt                     0.881228     0.856928    0.257980  0.064766
# total_pymnt_inv                 0.913257     0.817416    0.247119  0.071647
# total_rec_prncp                 0.845848     0.850773    0.259571  0.041316
# total_rec_int                   0.730914     0.634725    0.185476  0.106071
# total_rec_late_fee              0.027172     0.056709    0.006243 -0.011781
# recoveries                      0.123759     0.118152    0.021589  0.024878
# collection_recovery_fee         0.060358     0.075467    0.015604  0.011033
# last_pymnt_amnt                 0.442604     0.401688    0.140401  0.005212
# pub_rec_bankruptcies           -0.042746    -0.034103   -0.016801  0.005691
#
#                          delinq_2yrs  inq_last_6mths          ...           \
# id                         -0.008644       -0.042378          ...
# member_id                  -0.008119       -0.047086          ...
# loan_amnt                  -0.031864        0.009229          ...
# funded_amnt                -0.032355        0.009259          ...
# funded_amnt_inv            -0.038501       -0.005712          ...
# installment                -0.019657        0.009722          ...
# annual_inc                  0.023083        0.033908          ...
# dti                        -0.034452        0.001405          ...
# delinq_2yrs                 1.000000        0.008091          ...
# inq_last_6mths              0.008091        1.000000          ...
# mths_since_last_delinq     -0.569438       -0.003851          ...
# mths_since_last_record     -0.036628       -0.027878          ...
# open_acc                    0.011656        0.091713          ...
# pub_rec                     0.007463        0.024802          ...
# revol_bal                  -0.055125       -0.022381          ...
# total_acc                   0.067892        0.111499          ...
# out_prncp                  -0.003008       -0.012106          ...
# out_prncp_inv              -0.003203       -0.011780          ...
# total_pymnt                -0.022695       -0.010559          ...
# total_pymnt_inv            -0.028976       -0.020277          ...
# total_rec_prncp            -0.038795       -0.023433          ...
# total_rec_int               0.023077        0.021774          ...
# total_rec_late_fee          0.030609        0.031215          ...
# recoveries                  0.012315        0.018972          ...
# collection_recovery_fee     0.013912        0.012420          ...
# last_pymnt_amnt            -0.012149        0.028514          ...
# pub_rec_bankruptcies        0.003375        0.016346          ...
#
#                          out_prncp_inv  total_pymnt  total_pymnt_inv  \
# id                            0.180591     0.140045         0.220838
# member_id                     0.170706     0.139975         0.229307
# loan_amnt                     0.192623     0.886613         0.854243
# funded_amnt                   0.194675     0.903160         0.870799
# funded_amnt_inv               0.203693     0.881228         0.913257
# installment                   0.124932     0.856928         0.817416
# annual_inc                    0.033472     0.257980         0.247119
# dti                           0.036012     0.064766         0.071647
# delinq_2yrs                  -0.003203    -0.022695        -0.028976
# inq_last_6mths               -0.011780    -0.010559        -0.020277
# mths_since_last_delinq        0.005501     0.012174         0.057515
# mths_since_last_record        0.056635     0.004355         0.373132
# open_acc                      0.028514     0.162663         0.152937
# pub_rec                      -0.012910    -0.053668        -0.054101
# revol_bal                     0.060183     0.293204         0.277543
# total_acc                     0.031009     0.225077         0.219244
# out_prncp                     0.999827     0.239367         0.246537
# out_prncp_inv                 1.000000     0.239049         0.246524
# total_pymnt                   0.239049     1.000000         0.970815
# total_pymnt_inv               0.246524     0.970815         1.000000
# total_rec_prncp               0.166235     0.971472         0.939581
# total_rec_int                 0.383410     0.828758         0.815615
# total_rec_late_fee           -0.004752     0.012981        -0.000796
# recoveries                   -0.018858     0.023950         0.017862
# collection_recovery_fee      -0.011382     0.024555         0.015016
# last_pymnt_amnt              -0.066324     0.474624         0.462255
# pub_rec_bankruptcies         -0.010314    -0.043661        -0.047011
#
#                          total_rec_prncp  total_rec_int  total_rec_late_fee  \
# id                              0.112213       0.172856           -0.055082
# member_id                       0.112168       0.173234           -0.057750
# loan_amnt                       0.852021       0.729726            0.044706
# funded_amnt                     0.870255       0.737469            0.046705
# funded_amnt_inv                 0.845848       0.730914            0.027172
# installment                     0.850773       0.634725            0.056709
# annual_inc                      0.259571       0.185476            0.006243
# dti                             0.041316       0.106071           -0.011781
# delinq_2yrs                    -0.038795       0.023077            0.030609
# inq_last_6mths                 -0.023433       0.021774            0.031215
# mths_since_last_delinq          0.015708       0.002801           -0.028460
# mths_since_last_record         -0.041470       0.128281           -0.097503
# open_acc                        0.160631       0.124499           -0.018627
# pub_rec                        -0.065384      -0.007470           -0.002071
# revol_bal                       0.281419       0.243000            0.003823
# total_acc                       0.231242       0.147792           -0.024715
# out_prncp                       0.166519       0.383746           -0.004644
# out_prncp_inv                   0.166235       0.383410           -0.004752
# total_pymnt                     0.971472       0.828758            0.012981
# total_pymnt_inv                 0.939581       0.815615           -0.000796
# total_rec_prncp                 1.000000       0.684027           -0.019667
# total_rec_int                   0.684027       1.000000            0.069099
# total_rec_late_fee             -0.019667       0.069099            1.000000
# recoveries                     -0.094821       0.075552            0.099925
# collection_recovery_fee        -0.058634       0.033289            0.093178
# last_pymnt_amnt                 0.543408       0.191990           -0.060600
# pub_rec_bankruptcies           -0.054125      -0.003609           -0.005489
#
#                          recoveries  collection_recovery_fee  last_pymnt_amnt  \
# id                         0.033426                -0.013359         0.122365
# member_id                  0.031565                -0.015155         0.123627
# loan_amnt                  0.135446                 0.072853         0.448742
# funded_amnt                0.136284                 0.074676         0.453133
# funded_amnt_inv            0.123759                 0.060358         0.442604
# installment                0.118152                 0.075467         0.401688
# annual_inc                 0.021589                 0.015604         0.140401
# dti                        0.024878                 0.011033         0.005212
# delinq_2yrs                0.012315                 0.013912        -0.012149
# inq_last_6mths             0.018972                 0.012420         0.028514
# mths_since_last_delinq    -0.008622                -0.018697         0.007023
# mths_since_last_record    -0.013125                -0.038484         0.078624
# open_acc                   0.016396                 0.006219         0.078865
# pub_rec                   -0.005521                -0.005536        -0.032214
# revol_bal                  0.042091                 0.022400         0.120371
# total_acc                  0.023281                 0.010551         0.162841
# out_prncp                 -0.018878                -0.011394        -0.066393
# out_prncp_inv             -0.018858                -0.011382        -0.066324
# total_pymnt                0.023950                 0.024555         0.474624
# total_pymnt_inv            0.017862                 0.015016         0.462255
# total_rec_prncp           -0.094821                -0.058634         0.543408
# total_rec_int              0.075552                 0.033289         0.191990
# total_rec_late_fee         0.099925                 0.093178        -0.060600
# recoveries                 1.000000                 0.796816        -0.069955
# collection_recovery_fee    0.796816                 1.000000        -0.041874
# last_pymnt_amnt           -0.069955                -0.041874         1.000000
# pub_rec_bankruptcies      -0.004651                -0.005208        -0.022585
#
#                          pub_rec_bankruptcies
# id                                  -0.009505
# member_id                           -0.008769
# loan_amnt                           -0.037180
# funded_amnt                         -0.038502
# funded_amnt_inv                     -0.042746
# installment                         -0.034103
# annual_inc                          -0.016801
# dti                                  0.005691
# delinq_2yrs                          0.003375
# inq_last_6mths                       0.016346
# mths_since_last_delinq               0.025841
# mths_since_last_record               0.823352
# open_acc                             0.005930
# pub_rec                              0.847305
# revol_bal                           -0.049406
# total_acc                           -0.011807
# out_prncp                           -0.010024
# out_prncp_inv                       -0.010314
# total_pymnt                         -0.043661
# total_pymnt_inv                     -0.047011
# total_rec_prncp                     -0.054125
# total_rec_int                       -0.003609
# total_rec_late_fee                  -0.005489
# recoveries                          -0.004651
# collection_recovery_fee             -0.005208
# last_pymnt_amnt                     -0.022585
# pub_rec_bankruptcies                 1.000000
#
# [27 rows x 27 columns]

# %%
loanData['int_rate'] = loanData['int_rate'].str.rstrip('%').astype('float')

# %%
loanData = loanData.drop(['title', 'zip_code'], axis=1)

# %%
loanData['revol_util'] = loanData['revol_util'].str.rstrip('%').astype('float')

# %%
# Filter data of loan_status for only charged off and fully paid, as we don't need the current status coustomer
loanData = loanData[loanData['loan_status'].isin(['Charged Off','Fully Paid'])]
print(loanData.shape)
print(loanData.shape)
# Out:
# (38577, 48)
# (38577, 48)

# %%
loanData['loan_status'] = loanData['loan_status'].apply(lambda x: 0 if x=='Fully Paid' else 1)

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'application_type', 'pub_rec_bankruptcies', 'emp_length_range'],
#       dtype='object')

# %% [markdown]
# Univariate Analysis - Mithun

# %%
loan_col = ['loan_amnt','funded_amnt','funded_amnt_inv','annual_inc','installment','int_rate','dti','revol_bal',
           'open_acc','total_acc']

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plotting default rates across grade of the loan
sns.barplot(x='home_ownership', y='loan_status', data=loanData)
plt.show()
sns.barplot(x='verification_status', y='loan_status', data=loanData)
plt.show()
sns.barplot(x='issue_d', y='loan_status', data=loanData)
plt.show()

# %%
#Plotting histogram for defaulters and all customers to compare trends

loanData_defaulted = loanData.loc[loanData.loan_status == 1]

for col in list(loan_col):
    print(col)
    plt.figure(figsize=(8, 4))
    x = loanData[col]
    y = loanData_defaulted[col]
    plt.hist(x, 100, label='all customers')
    plt.hist(y, 100, label='default customers')
    plt.legend(loc='upper right')
    plt.xlabel(col)
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
# Out:
# loan_amnt
# funded_amnt
# funded_amnt_inv
# annual_inc
# installment
# int_rate
# dti
# revol_bal
# open_acc
# total_acc

# %% [markdown]
# ### bala - Feature analysis

# %%
loanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'application_type', 'pub_rec_bankruptcies', 'emp_length_range'],
#       dtype='object')

# %% [markdown]
# ### Grade Vs Loan status

# %%
loan_features = ['loan_status','grade','sub_grade','purpose','addr_state']

# %%
loan_features_df = pd.crosstab(columns=loanData.loan_status,index=loanData.grade)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
loan_features_df

#oan_features_df.columns[0].name="hai
loan_features_df.plot(kind='bar',figsize=(15,8))

# %% [markdown]
# ### Loan Status Vs Sub_grade

# %%
loan_features_df = pd.crosstab(columns=loanData.loan_status,index=loanData.sub_grade)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
loan_features_df

#oan_features_df.columns[0].name="hai
loan_features_df.plot(kind='bar',figsize=(15,8))

# %% [markdown]
# ### Loan Status Vs Purpose

# %%
loan_features_df = pd.crosstab(columns=loanData.loan_status,index=loanData.purpose)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
loan_features_df

#oan_features_df.columns[0].name="hai
loan_features_df.plot(kind='bar',figsize=(15,8))

# %% [markdown]
# ### Loan Status Vs Addr_state

# %%
loan_features_df = pd.crosstab(columns=loanData.loan_status,index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
loan_features_df.plot(kind='bar',figsize=(15,8))

# %% [markdown]
# ### finding the defaluter impact by state and grade

# %%
loan_features_df = pd.crosstab(columns=[loanData.loan_status,loanData.grade],index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
plt.figure(figsize=(10,15))
sns.heatmap(data=loan_features_df['Defaulter'],annot=True, cmap="YlGnBu",fmt='g')

# %% [markdown]
# ### finding the defaluter impact by state and Purpose

# %%
loan_features_df = pd.crosstab(columns=[loanData.loan_status,loanData.purpose],index=loanData.addr_state)
loan_features_df.rename(
  columns={
    0 : 'All',
    1 : 'Defaulter'
  },
  inplace=True
)
plt.figure(figsize=(10,15))
sns.heatmap(data=loan_features_df['Defaulter'],annot=True, cmap="YlGnBu",fmt='g')

# %% [markdown]
#    ### loan Data Univariate analysis

# %% [markdown]
# ###### Arpita : Start : 31/01/2019

# %%
loanData.to_csv('loanData_afterCleaning.csv', sep=',')

# %%
pd.pivot_table(loanData, index=['annual_inc'], values=['member_id'],aggfunc=np.sum)
# Out:
#              member_id
# annual_inc
# 4000.00       518840.0
# 4080.00       678265.0
# 4200.00      1029185.0
# 4800.00      2413520.0
# 4888.00       507853.0
# 5000.00       184901.0
# 5500.00       440811.0
# 6000.00      3956032.0
# 7000.00       512743.0
# 7200.00      3216672.0
# 7500.00       621672.0
# 7800.00       635352.0
# 7904.04       242682.0
# 8000.00      4368083.0
# 8004.00       766062.0
# 8088.00      2297469.0
# 8280.00      1243770.0
# 8400.00      3921157.0
# 8412.00       691611.0
# 8472.00      1067848.0
# 8500.00       300009.0
# 8628.00      1811664.0
# 9000.00      1735256.0
# 9081.00       627176.0
# 9192.00       727535.0
# 9240.00      1092812.0
# 9600.00     21250005.0
# 9732.00       405958.0
# 9840.00       976107.0
# 9900.00       684236.0
# ...                ...
# 648000.00    2360672.0
# 660000.00     656013.0
# 667680.00     765740.0
# 700000.00    1008802.0
# 700053.85     716659.0
# 708000.00     576961.0
# 720000.00    1248945.0
# 725000.00    1088144.0
# 741600.00     670637.0
# 750000.00    2088430.0
# 756000.00     752220.0
# 762000.00     580691.0
# 780000.00    3437866.0
# 800000.00     625309.0
# 828000.00     797223.0
# 840000.00     665304.0
# 889000.00     757100.0
# 900000.00    2827097.0
# 948000.00     824049.0
# 1080000.00    682915.0
# 1176000.00    710553.0
# 1200000.00   2924671.0
# 1250000.00   1039166.0
# 1362000.00    561049.0
# 1440000.00    571287.0
# 1782000.00   1100269.0
# 1900000.00    784585.0
# 2039784.00    267741.0
# 3900000.00    672152.0
# 6000000.00    663575.0
#
# [5215 rows x 1 columns]

# %%
pd.pivot_table(loanData, index=['pub_rec_bankruptcies'], values=['member_id'],aggfunc=len)
# Out:
#                       member_id
# pub_rec_bankruptcies
# 0.0                     36238.0
# 1.0                      1637.0
# 2.0                         5.0

# %% [markdown]
# ### Filter the customers whose loan status is either 'Current' or 'Charged Off'

# %%
loanDataCurrent_ChargedOff = loanData.loc[(loanData['loan_status']=='Charged Off') | (loanData['loan_status']=='Current')]
loanDataCurrent_ChargedOff.to_csv('loanData_onlyCurrentAndChargedOff.csv')
# Out:
# C:\Users\bgurusam\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py:1164: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-bcce652055e9> in <module>()
# ----> 1 loanDataCurrent_ChargedOff = loanData.loc[(loanData['loan_status']=='Charged Off') | (loanData['loan_status']=='Current')]
#       2 loanDataCurrent_ChargedOff.to_csv('loanData_onlyCurrentAndChargedOff.csv')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1251
#    1252             with np.errstate(all='ignore'):
# -> 1253                 res = na_op(values, other)
#    1254             if is_scalar(res):
#    1255                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1164                     result = method(y)
#    1165                 if result is NotImplemented:
# -> 1166                     raise TypeError("invalid type comparison")
#    1167             else:
#    1168                 result = op(x, y)
#
# TypeError: invalid type comparison

# %% [markdown]
# ### Filter the customers whose loan status is Charged Off

# %%
pd.pivot_table(loanData, index=['loan_status'], values=['member_id'],aggfunc=len)

# %%
loanDataChargedOff = loanData.loc[loanData['loan_status']=='Charged Off']

# %%
loanDataChargedOff.head(10)

# %% [markdown]
# ### No. of Charged-Off cases with derogatory public records

# %%
pd.pivot_table(loanDataChargedOff, index=['pub_rec'], values=['member_id'],aggfunc=len)

# %% [markdown]
# ### No. of Charged-Off cases with credit inquiries in last 6 months

# %%
temp_df = pd.pivot_table(loanDataChargedOff, index=['inq_last_6mths'], values=['member_id'],aggfunc=len)
temp_df.sort_values(by='inq_last_6mths', ascending=False)

# %%
## List of members with loan status 'Charged-off' having max. credit inquiries (8) in last 6 months
loanDataChargedOff.loc[loanDataChargedOff['inq_last_6mths']==8]

# %% [markdown]
# ### Are there any member_ids with Charged-off loan status that are duplicated?

# %%
loanDataChargedOff_memberids = loanDataChargedOff['member_id']
loanDataChargedOff[loanDataChargedOff_memberids.isin(loanDataChargedOff_memberids[loanDataChargedOff_memberids.duplicated()])]

# %% [markdown]
# ###### Arpita : End : 31/01/2019
